# %% [markdown]
# # Open and visualize the data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
PATH_CSV="/Users/iris/Documents/radar_deep/Radar_Traffic_Counts.csv"

# %%
df=pd.read_csv(PATH_CSV,parse_dates={"global_date":[3,4,5,9]},keep_date_col=True)

# %%
df.head()
# Out:
#           global_date                                      location_name  \
# 0 2018-01-23 22:15:00         2021 BLK KINNEY AVE (NW 300ft NW of Lamar)
# 1 2017-12-16 19:45:00                 CAPITAL OF TEXAS HWY / LAKEWOOD DR
# 2 2018-01-23 21:45:00  400 BLK AZIE MORTON RD (South of Barton Spring...
# 3 2018-01-23 21:45:00  400 BLK AZIE MORTON RD (South of Barton Spring...
# 4 2018-01-23 22:15:00         2021 BLK KINNEY AVE (NW 300ft NW of Lamar)
#
#    location_latitude  location_longitude  Year Month Day  Day of Week  Hour  \
# 0          30.248691          -97.770409  2018     1  23            2    22
# 1          30.371674          -97.785660  2017    12  16            6    19
# 2          30.264245          -97.765802  2018     1  23            2    21
# 3          30.264245          -97.765802  2018     1  23            2    21
# 4          30.248691          -97.770409  2018     1  23            2    22
#
#    Minute Time Bin Direction  Volume
# 0      15    22:15      None       4
# 1      45    19:45        NB     103
# 2      45    21:45        SB      44
# 3      45    21:45        NB      13
# 4      15    22:15      None       0

# %%
#df["datetime_time"]=df.apply(lambda x: datetime.datetime(x.Year,x.Month,x.Day,x.Hour,x.Minute),axis=1)

# %%
df.columns
# Out:
# Index(['global_date', 'location_name', 'location_latitude',
#        'location_longitude', 'Year', 'Month', 'Day', 'Day of Week', 'Hour',
#        'Minute', 'Time Bin', 'Direction', 'Volume'],
#       dtype='object')

# %%
df["Time Bin"].unique()[:10]
# Out:
# array(['22:15', '19:45', '21:45', '19:30', '22:00', '21:00', '22:30',
#        '22:45', '23:00', '10:45'], dtype=object)

# %%
print(df['location_name'].unique().shape)
radar1=df['location_name'].unique()[1]
# Out:
# (23,)

# %%
radar1
# Out:
# ' CAPITAL OF TEXAS HWY / LAKEWOOD DR'

# %%
df[["Day","Month","Year"]][df['location_name']==radar1] #we can seet we have data for each
# Out:
#         Day Month  Year
# 1        16    12  2017
# 26       16    12  2017
# 27       16    12  2017
# 35       23     1  2018
# 36       23     1  2018
# ...      ..   ...   ...
# 4603784  27     5  2019
# 4603801  25     5  2019
# 4603818  21     5  2019
# 4603821  20     5  2019
# 4603843  17     5  2019
#
# [383244 rows x 3 columns]

# %%
df["global_date"][df['location_name']==radar1].unique()
# Out:
# array(['2017-12-16T19:45:00.000000000', '2017-12-16T19:30:00.000000000',
#        '2018-01-23T22:15:00.000000000', ...,
#        '2019-05-07T23:45:00.000000000', '2019-05-07T23:30:00.000000000',
#        '2019-05-07T23:15:00.000000000'], dtype='datetime64[ns]')

# %%
sub_df=df[(df['location_name']==radar1)]

# %%
sub_df["Direction"].unique()
# Out:
# array(['NB', 'SB'], dtype=object)

# %%
datetime.date(2018,1,23)
# Out:
# datetime.date(2018, 1, 23)

# %%
print(type(sub_df["global_date"].iloc[0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
select_date=pd.Timestamp(year=2018,month=1,day=23,unit="D").date()

# %%
print(select_date)
# Out:
# 2018-01-23

# %%
sub_df.rename({"Time Bin":"date"})
# Out:
#                    Time Bin Direction  Volume
# 0       2020-11-23 22:15:00      None       4
# 4       2020-11-23 22:15:00      None       0
# 21      2020-11-23 22:15:00      None       3
# 67      2020-11-23 22:00:00      None       4
# 68      2020-11-23 22:00:00      None       1
# ...                     ...       ...     ...
# 1483732 2020-11-23 10:45:00      None       5
# 1483821 2020-11-23 10:30:00      None      12
# 1483822 2020-11-23 10:30:00      None       2
# 1483823 2020-11-23 10:30:00      None       5
# 1483824 2020-11-23 10:30:00      None       5
#
# [54432 rows x 3 columns]

# %%
sub_df
# Out:
#                 global_date                        location_name  \
# 1       2017-12-16 19:45:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# 26      2017-12-16 19:30:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# 27      2017-12-16 19:30:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# 35      2018-01-23 22:15:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# 36      2018-01-23 22:15:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# ...                     ...                                  ...
# 4603784 2019-05-27 18:00:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# 4603801 2019-05-25 04:45:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# 4603818 2019-05-21 13:00:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# 4603821 2019-05-20 15:00:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# 4603843 2019-05-17 00:00:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
#
#          location_latitude  location_longitude  Year Month Day  Day of Week  \
# 1                30.371674           -97.78566  2017    12  16            6
# 26               30.371674           -97.78566  2017    12  16            6
# 27               30.371674           -97.78566  2017    12  16            6
# 35               30.371674           -97.78566  2018     1  23            2
# 36               30.371674           -97.78566  2018     1  23            2
# ...                    ...                 ...   ...   ...  ..          ...
# 4603784          30.371674           -97.78566  2019     5  27            1
# 4603801          30.371674           -97.78566  2019     5  25            6
# 4603818          30.371674           -97.78566  2019     5  21            2
# 4603821          30.371674           -97.78566  2019     5  20            1
# 4603843          30.371674           -97.78566  2019     5  17            5
#
#          Hour  Minute Time Bin Direction  Volume
# 1          19      45    19:45        NB     103
# 26         19      30    19:30        NB     136
# 27         19      30    19:30        NB     106
# 35         22      15    22:15        NB      58
# 36         22      15    22:15        NB      57
# ...       ...     ...      ...       ...     ...
# 4603784    18       0    18:00        SB      80
# 4603801     4      45    04:45        NB       2
# 4603818    13       0    13:00        SB       2
# 4603821    15       0    15:00        SB     175
# 4603843     0       0    00:00        SB       0
#
# [383244 rows x 13 columns]

# %%
s2=sub_df[sub_df.apply(lambda x: x["global_date"].date())]
s2[s2["global_date"]==select_date]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/dl_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'global_date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-66f5a322f652> in <module>
# ----> 1 s2=sub_df[sub_df.apply(lambda x: x["global_date"].date())]
#       2 s2[s2["global_date"]==select_date]
#
# ~/opt/anaconda3/envs/dl_env/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7546             kwds=kwds,
#    7547         )
# -> 7548         return op.get_result()
#    7549
#    7550     def applymap(self, func) -> "DataFrame":
#
# ~/opt/anaconda3/envs/dl_env/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# ~/opt/anaconda3/envs/dl_env/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     269
#     270     def apply_standard(self):
# --> 271         results, res_index = self.apply_series_generator()
#     272
#     273         # wrap results
#
# ~/opt/anaconda3/envs/dl_env/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     298                 for i, v in enumerate(series_gen):
#     299                     # ignore SettingWithCopy here in case the user mutates
# --> 300                     results[i] = self.f(v)
#     301                     if isinstance(results[i], ABCSeries):
#     302                         # If we have a view on v, we need to make a copy because
#
# <ipython-input-59-66f5a322f652> in <lambda>(x)
# ----> 1 s2=sub_df[sub_df.apply(lambda x: x["global_date"].date())]
#       2 s2[s2["global_date"]==select_date]
#
# ~/opt/anaconda3/envs/dl_env/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# ~/opt/anaconda3/envs/dl_env/lib/python3.7/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     987
#     988         # Similar to Index.get_value, but we do not fall back to positional
# --> 989         loc = self.index.get_loc(label)
#     990         return self.index._get_values_for_loc(self, loc, label)
#     991
#
# ~/opt/anaconda3/envs/dl_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'global_date'

# %%
sub_df[(sub_df["Direction"]=="NB")|(sub_df["Year"]==2018)].sort_values("global_date")
# Out:
#                 global_date                        location_name  \
# 1541335 2017-09-03 02:15:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# 1541334 2017-09-03 02:15:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# 1541281 2017-09-03 02:15:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# 1541280 2017-09-03 02:15:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# 1541214 2017-09-03 02:30:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# ...                     ...                                  ...
# 3595389 2019-11-12 11:00:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# 3518310 2019-11-12 11:15:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# 3595355 2019-11-12 11:15:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# 3595282 2019-11-12 11:30:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# 3595279 2019-11-12 11:30:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
#
#          location_latitude  location_longitude  Year Month Day  Day of Week  \
# 1541335          30.371674           -97.78566  2017     9   3            0
# 1541334          30.371674           -97.78566  2017     9   3            0
# 1541281          30.371674           -97.78566  2017     9   3            0
# 1541280          30.371674           -97.78566  2017     9   3            0
# 1541214          30.371674           -97.78566  2017     9   3            0
# ...                    ...                 ...   ...   ...  ..          ...
# 3595389          30.371674           -97.78566  2019    11  12            2
# 3518310          30.371674           -97.78566  2019    11  12            2
# 3595355          30.371674           -97.78566  2019    11  12            2
# 3595282          30.371674           -97.78566  2019    11  12            2
# 3595279          30.371674           -97.78566  2019    11  12            2
#
#          Hour  Minute Time Bin Direction  Volume
# 1541335     2       9    02:15        NB       9
# 1541334     2       9    02:15        NB      14
# 1541281     2      15    02:15        NB       3
# 1541280     2      15    02:15        NB      11
# 1541214     2      30    02:30        NB       7
# ...       ...     ...      ...       ...     ...
# 3595389    11       0    11:00        NB     106
# 3518310    11      15    11:15        NB     117
# 3595355    11      15    11:15        NB     135
# 3595282    11      30    11:30        NB     184
# 3595279    11      30    11:30        NB     146
#
# [127748 rows x 13 columns]

# %%
sub_df2018=sub_df[(sub_df["Direction"]=="NB")|(sub_df["Year"]==2018)]

# %%
sub_df2018.sort_values("global_date")
# Out:
#                 global_date                        location_name  \
# 1541335 2017-09-03 02:15:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# 1541334 2017-09-03 02:15:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# 1541281 2017-09-03 02:15:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# 1541280 2017-09-03 02:15:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# 1541214 2017-09-03 02:30:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# ...                     ...                                  ...
# 3595389 2019-11-12 11:00:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# 3518310 2019-11-12 11:15:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# 3595355 2019-11-12 11:15:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# 3595282 2019-11-12 11:30:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
# 3595279 2019-11-12 11:30:00   CAPITAL OF TEXAS HWY / LAKEWOOD DR
#
#          location_latitude  location_longitude  Year Month Day  Day of Week  \
# 1541335          30.371674           -97.78566  2017     9   3            0
# 1541334          30.371674           -97.78566  2017     9   3            0
# 1541281          30.371674           -97.78566  2017     9   3            0
# 1541280          30.371674           -97.78566  2017     9   3            0
# 1541214          30.371674           -97.78566  2017     9   3            0
# ...                    ...                 ...   ...   ...  ..          ...
# 3595389          30.371674           -97.78566  2019    11  12            2
# 3518310          30.371674           -97.78566  2019    11  12            2
# 3595355          30.371674           -97.78566  2019    11  12            2
# 3595282          30.371674           -97.78566  2019    11  12            2
# 3595279          30.371674           -97.78566  2019    11  12            2
#
#          Hour  Minute Time Bin Direction  Volume
# 1541335     2       9    02:15        NB       9
# 1541334     2       9    02:15        NB      14
# 1541281     2      15    02:15        NB       3
# 1541280     2      15    02:15        NB      11
# 1541214     2      30    02:30        NB       7
# ...       ...     ...      ...       ...     ...
# 3595389    11       0    11:00        NB     106
# 3518310    11      15    11:15        NB     117
# 3595355    11      15    11:15        NB     135
# 3595282    11      30    11:30        NB     184
# 3595279    11      30    11:30        NB     146
#
# [127748 rows x 13 columns]

# %%
print(sub_df2018["global_date"].iloc[0])
print(type(sub_df2018["global_date"].iloc[0].date()))
from datetime import timedelta
add_D=timedelta(days=20)
sub_df2018["global_date"].iloc[0].date()+add_D
# Out:
# 2017-12-16 19:45:00
# <class 'datetime.date'>
# datetime.date(2018, 1, 5)

# %%
days_df=sub_df2018.groupby(["Year","Month","Day"]).agg({"Volume":"sum"}).reset_index()

# %%
days_df
# Out:
#      Year Month Day  Volume
# 0    2017    10   1   19448
# 1    2017    10  10   17416
# 2    2017    10  11   17804
# 3    2017    10  12   17676
# 4    2017    10  13   17097
# ..    ...   ...  ..     ...
# 692  2019     9   5   21760
# 693  2019     9   6   22842
# 694  2019     9   7   17745
# 695  2019     9   8   15246
# 696  2019     9   9   20368
#
# [697 rows x 4 columns]

# %%
final_df=sub_df2018.groupby("global_date").agg({"Volume":"sum"}).sort_values("global_date").reset_index()

# %%
# It seems that some radar has collect data with no direction ...

# %%
mean_df=sub_df2018.groupby(["Day of Week","Time Bin"]).agg({"Volume":"mean"}).sort_values("Day of Week").reset_index()

# %%
mean_df
# Out:
#      Day of Week Time Bin      Volume
# 0              0    00:00   45.536082
# 1              0    17:15  129.515464
# 2              0    17:00  137.577320
# 3              0    16:45  136.329897
# 4              0    16:30  141.530928
# ..           ...      ...         ...
# 667            6    06:30   22.675258
# 668            6    06:15   17.164948
# 669            6    05:45   10.902062
# 670            6    11:30  164.273684
# 671            6    23:45   50.593750
#
# [672 rows x 3 columns]

# %%
f,ax=plt.subplots(7,1,figsize=(10,30))
for i in range(7):
    s=mean_df[mean_df["Day of Week"]==i].sort_values("Time Bin")
    s.plot(x="Time Bin",y="Volume",ax=ax[i],title="Mean value of the Volume for day {} of the week".format(i))

# %%
mean_df.plot(x="Day of Week",y="Volume",kind="bar",title="Mean volume aggregate by the day of the week over the year 2018")
# Out:
# <AxesSubplot:title={'center':'Mean Volume aggregate by the day of the week over the year 2018'}, xlabel='Day of Week'>

# %%
final_df
# Out:
#               global_date  Volume
# 0     2017-09-03 02:15:00      37
# 1     2017-09-03 02:30:00      18
# 2     2017-09-03 02:45:00      14
# 3     2017-09-03 03:00:00      13
# 4     2017-09-03 03:15:00      19
# ...                   ...     ...
# 63642 2019-11-12 10:30:00     254
# 63643 2019-11-12 10:45:00     237
# 63644 2019-11-12 11:00:00     264
# 63645 2019-11-12 11:15:00     252
# 63646 2019-11-12 11:30:00     330
#
# [63647 rows x 2 columns]

# %%
final_df.columns
# Out:
# Index(['global_date', 'Volume'], dtype='object')

# %%
fig,ax=plt.subplots(7,1,figsize=(10,30))
for i in range(7):
    print(i*24*4,(i+1)*24*4)
    temp_df=final_df.iloc[i*24*4:(i+1)*24*4]
    temp_df.plot("global_date","Volume",ax=ax[i],title=" Day of the Week {}".format(i))
# Out:
# 0 96
# 96 192
# 192 288
# 288 384
# 384 480
# 480 576
# 576 672

# %%
final_df["exact_day"]=final_df["global_date"].date()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-52784744cd84> in <module>
# ----> 1 final_df["exact_day"]=final_df["global_date"].date()
#
# ~/opt/anaconda3/envs/dl_env/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'date'

# %%
final_df.plot("global_date","Volume")
# Out:
# <AxesSubplot:xlabel='global_date'>

# %%
sub_df[(sub_df["Direction"]=="SB")|(sub_df["Hour"]==21)]

# %%
sub_df[(sub_df["Direction"]=="SB")].plot(x="Time Bin",y="Volume")
